# %% [markdown]
# <a href="https://colab.research.google.com/github/ajay-aju-0/data-science/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import sklearn
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
diabetes = load_diabetes()
x = diabetes.data[:, np.newaxis, 2]
x
# Out:
# array([[ 0.06169621],
#        [-0.05147406],
#        [ 0.04445121],
#        [-0.01159501],
#        [-0.03638469],
#        [-0.04069594],
#        [-0.04716281],
#        [-0.00189471],
#        [ 0.06169621],
#        [ 0.03906215],
#        [-0.08380842],
#        [ 0.01750591],
#        [-0.02884001],
#        [-0.00189471],
#        [-0.02560657],
#        [-0.01806189],
#        [ 0.04229559],
#        [ 0.01211685],
#        [-0.0105172 ],
#        [-0.01806189],
#        [-0.05686312],
#        [-0.02237314],
#        [-0.00405033],
#        [ 0.06061839],
#        [ 0.03582872],
#        [-0.01267283],
#        [-0.07734155],
#        [ 0.05954058],
#        [-0.02129532],
#        [-0.00620595],
#        [ 0.04445121],
#        [-0.06548562],
#        [ 0.12528712],
#        [-0.05039625],
#        [-0.06332999],
#        [-0.03099563],
#        [ 0.02289497],
#        [ 0.01103904],
#        [ 0.07139652],
#        [ 0.01427248],
#        [-0.00836158],
# ...

# %%
x_train = x[:-30]
x_test = x[-30:]

# %%
x_train
# Out:
# array([[ 0.06169621],
#        [-0.05147406],
#        [ 0.04445121],
#        [-0.01159501],
#        [-0.03638469],
#        [-0.04069594],
#        [-0.04716281],
#        [-0.00189471],
#        [ 0.06169621],
#        [ 0.03906215],
#        [-0.08380842],
#        [ 0.01750591],
#        [-0.02884001],
#        [-0.00189471],
#        [-0.02560657],
#        [-0.01806189],
#        [ 0.04229559],
#        [ 0.01211685],
#        [-0.0105172 ],
#        [-0.01806189],
#        [-0.05686312],
#        [-0.02237314],
#        [-0.00405033],
#        [ 0.06061839],
#        [ 0.03582872],
#        [-0.01267283],
#        [-0.07734155],
#        [ 0.05954058],
#        [-0.02129532],
#        [-0.00620595],
#        [ 0.04445121],
#        [-0.06548562],
#        [ 0.12528712],
#        [-0.05039625],
#        [-0.06332999],
#        [-0.03099563],
#        [ 0.02289497],
#        [ 0.01103904],
#        [ 0.07139652],
#        [ 0.01427248],
#        [-0.00836158],
# ...

# %%
x_test
# Out:
# array([[ 0.08540807],
#        [-0.00081689],
#        [ 0.00672779],
#        [ 0.00888341],
#        [ 0.08001901],
#        [ 0.07139652],
#        [-0.02452876],
#        [-0.0547075 ],
#        [-0.03638469],
#        [ 0.0164281 ],
#        [ 0.07786339],
#        [-0.03961813],
#        [ 0.01103904],
#        [-0.04069594],
#        [-0.03422907],
#        [ 0.00564998],
#        [ 0.08864151],
#        [-0.03315126],
#        [-0.05686312],
#        [-0.03099563],
#        [ 0.05522933],
#        [-0.06009656],
#        [ 0.00133873],
#        [-0.02345095],
#        [-0.07410811],
#        [ 0.01966154],
#        [-0.01590626],
#        [-0.01590626],
#        [ 0.03906215],
#        [-0.0730303 ]])

# %%
y_train = diabetes.target[:-30]
y_test = diabetes.target[-30:]

# %%
regr = LinearRegression()
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regr.predict(x_test)
y_pred
# Out:
# array([233.80294072, 152.62808714, 159.73088683, 161.76025817,
#        228.72951237, 220.61202701, 130.3050024 , 101.89380365,
#        119.14346004, 168.86305786, 226.70014103, 116.09940303,
#        163.78962951, 115.08471736, 121.17283138, 158.71620116,
#        236.84699773, 122.18751705,  99.86443231, 124.21688839,
#        205.39174197,  96.8203753 , 154.65745848, 131.31968807,
#         83.62946159, 171.90711487, 138.42248776, 138.42248776,
#        190.17145692,  84.64414726])

# %%
regr.coef_  # coefficient calculation
# Out:
# array([941.43097333])

# %%
mean_squared_error(y_test, y_pred) # mean squared error calculation
# Out:
# 3035.0601152912686

# %%
r2_score(y_test, y_pred)  # r_score calculation
# Out:
# 0.41092072813583513

# %%
plt.scatter(x_test, y_test, color='blue')
plt.plot(x_test, y_pred, color='red', linewidth=3)
plt.xticks(())
plt.yticks(())
plt.show()
